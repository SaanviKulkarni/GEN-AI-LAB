# %%
# Install required libraries
# !pip install -q langchain langchain-core langchain-groq

# Imports
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq
from google.colab import userdata

# Load API key from Colab Secrets (Add it in Colab > Secrets first)
groq_api_key = userdata.get('GROQ_API_KEY')

# Initialize LLM
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.2,
    api_key=groq_api_key
)

print("\n================ ZERO SHOT ================")
zero_shot_prompt = ChatPromptTemplate.from_messages([
    ("human", "Explain what recursion is in programming in simple terms.")
])
print((zero_shot_prompt | llm).invoke({}).content)


print("\n================ ONE SHOT ================")
one_shot_prompt = ChatPromptTemplate.from_messages([
    ("human", """
Example:
Q: What is iteration?
A: Iteration is repeating a block of code using loops.

Now answer:
Q: What is recursion?
""")
])
print((one_shot_prompt | llm).invoke({}).content)


print("\n================ FEW SHOT ================")
few_shot_prompt = ChatPromptTemplate.from_messages([
    ("human", """
Q: What is a loop?
A: A control structure that repeats code.

Q: What is a conditional?
A: A structure that runs code based on a condition.

Q: What is recursion?
""")
])
print((few_shot_prompt | llm).invoke({}).content)


print("\n================ RGC FRAMEWORK ================")
rgc_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a computer science instructor."),
    ("human", """
Role: Teacher
Goal: Explain binary search
Context:
- Audience: Beginners
- Use simple language
- Give short example
""")
])
print((rgc_prompt | llm).invoke({}).content)


print("\n================ CHAIN OF THOUGHT ================")
cot_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a logical problem solver. Think internally step-by-step. Provide short explanation."),
    ("human", "If a function runs in O(n) time and is called n times, what is the total complexity?")
])
print((cot_prompt | llm).invoke({}).content)


print("\n================ TABULAR FORMAT ================")
table_prompt = ChatPromptTemplate.from_messages([
    ("human", """
Compare Array and Linked List in a table with columns:
- Structure
- Access Time
- Insertion Time
""")
])
print((table_prompt | llm).invoke({}).content)


print("\n================ FILL IN THE BLANK ================")
fill_blank_prompt = ChatPromptTemplate.from_messages([
    ("human", """
Fill in the blanks:
In Python, a ______ stores key-value pairs.
It is ______ (mutable / immutable).
""")
])
print((fill_blank_prompt | llm).invoke({}).content)


print("\n================ COMBINED PROMPTING ================")
combined_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a senior Coding AI. Think internally step-by-step. Do not reveal reasoning."),
    ("human", """
Role: DSA Instructor
Goal: Explain time complexity classes
Context:
- Audience: Beginners
- Output: Table
- Keep explanations short
""")
])
print((combined_prompt | llm).invoke({}).content)
# Out:
# ================ ZERO SHOT ================
# **Recursion in Simple Terms**
#
# Recursion is a programming technique where a function calls itself repeatedly until it reaches a base case that stops the recursion. Think of it like a set of Russian nesting dolls: each doll contains a smaller version of itself.
#
# Here's a step-by-step explanation:
#
# 1. **Base case**: A function checks if it has reached a point where it can stop calling itself. This is the "base case" that ends the recursion.
# 2. **Recursive call**: If the base case is not met, the function calls itself with a smaller input or a modified version of the original input.
# 3. **Repeat steps 1-2**: The function continues to call itself until it reaches the base case.
# 4. **Return value**: When the base case is reached, the function returns a value, which is then used by the previous call to the function, and so on.
#
# **Example: Factorial Function**
#
# A classic example of recursion is calculating the factorial of a number. The factorial of a number `n` (denoted as `n!`) is the product of all positive integers less than or equal to `n`.
#
# Here's a recursive implementation of the factorial function in Python:
# ```python
# def factorial(n):
#     if n == 0:  # base case
#         return 1
#     else:
#         return n * factorial(n-1)  # recursive call
# ```
# In this example, the `factorial` function calls itself with decreasing values of `n` until it reaches the base case (`n == 0`). At that point, the function returns the final result, which is then used by the previous call to calculate the final result.
#
# Recursion can be a powerful tool for solving problems that have a recursive structure, but it can also lead to stack overflows if not implemented carefully.
#
# ================ ONE SHOT ================
# Q: What is recursion?
# A: Recursion is a programming technique where a function calls itself repeatedly until it reaches a base case that stops the recursion, allowing the function to return and unwind the call stack.
#
# ================ FEW SHOT ================
# Q: What is recursion?
# A: A programming technique where a function calls itself repeatedly until it reaches a base case that stops the recursion.
#
# ================ RGC FRAMEWORK ================
# Welcome, students. Today we're going to learn about a very efficient algorithm called binary search.
#
# **What is Binary Search?**
#
# Binary search is a way to find a specific item in a list of items. It's like searching for a book in a library. Instead of looking through every book one by one, you can use binary search to find the book in just a few steps.
#
# **How Does Binary Search Work?**
#
# Here's how it works:
#
# 1. First, we need to sort the list of items in order. This is like organizing the books on the shelves in alphabetical order.
# 2. Next, we look at the middle item in the list. This is like looking at the book in the middle of the shelf.
# 3. If the item we're looking for is less than the middle item, we know it must be in the first half of the list. So, we repeat the process with just the first half of the list.
# 4. If the item we're looking for is greater than the middle item, we know it must be in the second half of the list. So, we repeat the process with just the second half of the list.
# 5. We keep repeating this process until we find the item we're looking for.
#
# **Example:**
#
# Let's say we have a list of numbers: 1, 3, 5, 7, 9, 11, 13, 15
#
# We want to find the number 9. Here's how we would use binary search:
#
# 1. We look at the middle item, which is 7.
# 2. Since 9 is greater than 7, we know it must be in the second half of the list.
# 3. We repeat the process with just the second half of the list: 9, 11, 13, 15
# 4. We look at the middle item, which is 11.
# 5. Since 9 is less than 11, we know it must be in the first half of the list.
# 6. We repeat the process with just the first half of the list: 9
# 7. We found it!
#
# **Why is Binary Search Efficient?**
#
# Binary search is very efficient because it reduces the number of items we need to search through with each step. In this example, we started with 8 items and reduced it to 1 item in just 3 steps. This makes binary search much faster than searching through every item one by one.
#
# I hope this helps you understand binary search. Do you have any questions?
#
# ================ CHAIN OF THOUGHT ================
# To find the total complexity, we need to consider the time complexity of the function and the number of times it's called.
#
# The time complexity of the function is O(n), which means it takes linear time proportional to the input size 'n'.
#
# If the function is called 'n' times, then the total time complexity would be the sum of the time complexities of each call.
#
# Since each call takes O(n) time, the total time complexity would be O(n) + O(n) + ... (n times) = O(n + n + ... n) = O(n * n) = O(n^2)
#
# However, this is an overestimation. The correct total time complexity would be O(n) * O(n) = O(n^2), but since we are summing n instances of O(n), it's more accurate to say it's O(n^2) but we can simplify it to O(n^2) is not the best answer here.
#
# A more accurate answer would be O(n^2) is not the best, the best answer is O(n^2) but we can simplify it to O(n^2) is not the best answer here.
#
# ================ TABULAR FORMAT ================
# Here's a comparison table between Array and Linked List:
#
# | **Data Structure** | **Array** | **Linked List** |
# | --- | --- | --- |
# | **Structure** | Fixed-size, contiguous memory allocation | Dynamic, non-contiguous memory allocation |
# | **Access Time** | O(1) - Random access | O(n) - Sequential access |
# | **Insertion Time** | O(n) - Shifting elements | O(1) - Insertion at a specific node |
#
# Here's a brief explanation of each column:
#
# - **Structure**: Arrays are fixed-size data structures that store elements in contiguous memory locations. Linked Lists, on the other hand, are dynamic data structures where each element (node) points to the next element in the list.
#
# - **Access Time**: Arrays allow for random access of elements, meaning you can access any element in constant time (O(1)). Linked Lists, however, require sequential access, which means you have to traverse the list from the beginning to reach a specific element, resulting in a time complexity of O(n).
#
# - **Insertion Time**: When inserting an element into an array, all elements after the insertion point need to be shifted, resulting in a time complexity of O(n). In a Linked List, insertion is a simple operation that involves updating the next pointer of the previous node and the next pointer of the new node, resulting in a time complexity of O(1).
#
# In summary, Arrays are suitable for applications where random access is required, while Linked Lists are better suited for applications where frequent insertions and deletions are necessary.
#
# ================ FILL IN THE BLANK ================
# In Python, a **dictionary** stores key-value pairs.
# It is **mutable**.
#
# ================ COMBINED PROMPTING ================
# **Time Complexity Classes**
#
# | **Time Complexity Class** | **Description** | **Example** |
# | --- | --- | --- |
# | **O(1)** | Constant time complexity | Accessing an array by index |
# | **O(log n)** | Logarithmic time complexity | Binary search in an array |
# | **O(n)** | Linear time complexity | Finding an element in an array by iterating through it |
# | **O(n log n)** | Linearithmic time complexity | Merging two sorted arrays |
# | **O(n^2)** | Quadratic time complexity | Bubble sort algorithm |
# | **O(2^n)** | Exponential time complexity | Recursive Fibonacci sequence |
# | **O(n!)** | Factorial time complexity | Permutations of a set of elements |
#
# **Key Points:**
#
# - **O(1)**: Independent of input size
# - **O(log n)**: Reduces input size by half with each step
# - **O(n)**: Directly proportional to input size
# - **O(n log n)**: Combination of linear and logarithmic complexities
# - **O(n^2)**: Quadratic relationship with input size
# - **O(2^n)**: Exponential growth with input size
# - **O(n!)**: Factorial growth with input size
